# %% [markdown]
# <a href="https://colab.research.google.com/github/Shreyasdhumal/assignment1/blob/main/Assignment%202.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
Name=input()
Age=input()
Class=input()
Clg=input()
"My name is {},Im {} years old,Studying in class {} and in clg {}".format(Name,Age,Class,Clg)
# Out:
# Shreyas
# 21
# TYBSC
# SPC
# 'My name is Shreyas,Im 21 years old,Studying in class TYBSC and in clg SPC'
