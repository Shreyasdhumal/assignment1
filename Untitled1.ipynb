# %%
print(22/7)
x,y=18,5
print("Addition",x+y)
print("Substraction",x-y)
print("Multiplication",x*y)
print("Divisions",x/y)
print("Powers",x**y)
print("Modulus",x%y)
print("Floor division",x//y)
import math
math.sqrt(x)
# Out:
# 3.142857142857143
# Addition 23
# Substraction 13
# Multiplication 90
# Divisions 3.6
# Powers 1889568
# Modulus 3
# Floor division 3
# 4.242640687119285
